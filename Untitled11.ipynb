# %%
# P2 is the probability of player 2 winning.
import numpy as np
r1=45
r2=45
s1=1433
s2=1685
def g(x):
    g=1/np.sqrt(1+3*(x**2)/np.pi**2)
    return g
# a=g(math.sqrt(r1**2+r2**2))*(s2-s1)

p2=1/(1+np.exp(-g(np.sqrt(r1**2+r2**2))*(s2-s1)))
print(p2)
# Out:
# 0.9992384277849788

# %%
import pandas as pd
from IPython.display import HTML
import numpy as np
import matplotlib.pyplot as plt
P=np.ones(500)
for i in range(1,500):
    p2=1/(1+np.exp(-g(150)*(i)))
    P[i-1]=p2
    
plt.figure(figsize=(20,10))
plt.plot(P)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
